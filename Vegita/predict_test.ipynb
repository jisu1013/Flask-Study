# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import pandas as pd
import sklearn
import numpy as np
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X = tf.placeholder(tf.float32, shape=(None,4))
Y = tf.placeholder(tf.float32, shape=[None,1])
W = tf.Variable(tf.random_normal([4,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
hypothesis = tf.matmul(X,W)+b

# %%
saver = tf.train.Saver()
model = tf.global_variables_initializer()

# %%
avg_tmp = float(input('평균온도: '))
min_tmp = float(input('최저온도: '))
max_tmp = float(input('최고온도: '))
rain_fall = float(input('강수량: '))
# Out:
# 평균온도: 15.5
# 최저온도: 3.5
# 최고온도: 20.5
# 강수량: 5

# %%
with tf.Session() as sess:
    sess.run(model)
    save_path = '/content/drive/MyDrive/웹개발/vegita/saved.cpkt'
    saver.restore(sess, save_path)
    data = ((avg_tmp,min_tmp,max_tmp,rain_fall), )
    arr = np.array(data, dtype=np.float32)
    x_data = arr[0:4]
    dict = sess.run(hypothesis, feed_dict={X:x_data})
    print(dict)
    print(dict[0])
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/웹개발/vegita/saved.cpkt
# [[36.861683]]
# [36.861683]
